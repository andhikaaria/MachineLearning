# %% [markdown]
# <a href="https://colab.research.google.com/github/andhikaaria/MachineLearning/blob/main/mgg1/LinearRegresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Buat data acak
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1)

# Buat model regresi linear dengan fitur polinomial
degree = 4  # Derajat polinomial
model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
model.fit(X, y)

# Prediksi
X_test = np.linspace(0, 10, 100).reshape(-1, 1)
y_pred = model.predict(X_test)

# Plot hasil
plt.scatter(X, y, label='Data')
plt.plot(X_test, y_pred, label='Model', color='r')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
